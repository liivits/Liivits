# %%
#suppress warningS 
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import numpy as np
import pandas as pd
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/mammographic-masses/mammographic_masses.data'
column_names = ["BI-RADS assessment", "age", "mass_shape","mass_margin","mass_density","class"]
df = pd.read_csv(url, header=None, names=column_names)
df.head(10)
# Out:
#   BI-RADS assessment age mass_shape mass_margin mass_density  class
# 0                  5  67          3           5            3      1
# 1                  4  43          1           1            ?      1
# 2                  5  58          4           5            3      1
# 3                  4  28          1           1            3      0
# 4                  5  74          1           5            ?      1
# 5                  4  65          1           ?            3      0
# 6                  4  70          ?           ?            3      0
# 7                  5  42          1           ?            3      0
# 8                  5  57          1           5            3      1
# 9                  5  60          ?           5            1      1

# %%
df = df.drop(columns=["BI-RADS assessment"])
#df = df.drop(columns=["severity"])
df.head()
# Out:
#   age mass_shape mass_margin mass_density  class
# 0  67          3           5            3      1
# 1  43          1           1            ?      1
# 2  58          4           5            3      1
# 3  28          1           1            3      0
# 4  74          1           5            ?      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 961 entries, 0 to 960
# Data columns (total 5 columns):
# age             961 non-null object
# mass_shape      961 non-null object
# mass_margin     961 non-null object
# mass_density    961 non-null object
# class           961 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 37.6+ KB

# %%
df.columns
# Out:
# Index(['age', 'mass_shape', 'mass_margin', 'mass_density', 'class'], dtype='object')

# %%
df = df.dropna(thresh=2) # dropping any rows with more than 2 values missing

# %%
df = df[df != '?'].copy(deep=True)
df.dropna(axis=0, how='all')
df = df.apply(pd.to_numeric)

for col in df.columns:
   df[col].fillna((df[col].mean()), inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
df.head()
# Out:
#     age  mass_shape  mass_margin  mass_density  class
# 0  67.0         3.0          5.0      3.000000      1
# 1  43.0         1.0          1.0      2.910734      1
# 2  58.0         4.0          5.0      3.000000      1
# 3  28.0         1.0          1.0      3.000000      0
# 4  74.0         1.0          5.0      2.910734      1

# %%
#from sklearn.preprocessing import Imputer
#imr = Imputer(missing_values='NaN', strategy='mean', axis=0)
#imr = imr.fit(df)
#df = imr.transform(df.values)
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961 entries, 0 to 960
# Data columns (total 5 columns):
# age             961 non-null float64
# mass_shape      961 non-null float64
# mass_margin     961 non-null float64
# mass_density    961 non-null float64
# class           961 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 45.0 KB

# %%
df.describe()
# Out:
#               age  mass_shape  mass_margin  mass_density       class
# count  961.000000  961.000000   961.000000    961.000000  961.000000
# mean    55.487448    2.721505     2.796276      2.910734    0.463059
# std     14.442373    1.222561     1.526880      0.365074    0.498893
# min     18.000000    1.000000     1.000000      1.000000    0.000000
# 25%     45.000000    2.000000     1.000000      3.000000    0.000000
# 50%     57.000000    3.000000     3.000000      3.000000    0.000000
# 75%     66.000000    4.000000     4.000000      3.000000    1.000000
# max     96.000000    4.000000     5.000000      4.000000    1.000000

# %%
df.head()
# Out:
#     age  mass_shape  mass_margin  mass_density  class
# 0  67.0         3.0          5.0      3.000000      1
# 1  43.0         1.0          1.0      2.910734      1
# 2  58.0         4.0          5.0      3.000000      1
# 3  28.0         1.0          1.0      3.000000      0
# 4  74.0         1.0          5.0      2.910734      1

# %%
df.isnull().sum()
# Out:
# age             0
# mass_shape      0
# mass_margin     0
# mass_density    0
# class           0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

corr = df.corr()
ax = sns.heatmap(corr, annot = True, cmap="coolwarm")

plt.setp(ax.axes.get_xticklabels(), rotation=45)
plt.title('Correlation Matrix for mammographic masses dataset')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix for mammographic masses dataset')

# %%
df.corr()
# Out:
#                    age  mass_shape  mass_margin  mass_density     class
# age           1.000000    0.359751     0.402749      0.027798  0.430754
# mass_shape    0.359751    1.000000     0.718898      0.069924  0.554349
# mass_margin   0.402749    0.718898     1.000000      0.100323  0.561230
# mass_density  0.027798    0.069924     0.100323      1.000000  0.061535
# class         0.430754    0.554349     0.561230      0.061535  1.000000

# %%
df.plot(kind= 'box' , subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(20,16), grid = True)
# Out:
# age                AxesSubplot(0.125,0.657941;0.227941x0.222059)
# mass_shape      AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# mass_margin     AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# mass_density       AxesSubplot(0.125,0.391471;0.227941x0.222059)
# class           AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# dtype: object

# %%
sns.distplot(df["age"],kde=False)

# %%
df.hist(figsize=(12,10),bins = 20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000287D7892FD0>,
# ...
#       dtype=object)

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

feature1 = df['mass_shape'].values
feature2 = df['mass_density'].values 
feature3 = df['mass_margin'].values


df['class']=df['class'].astype('str')

c = df['class'].values
df['class']=df['class'].astype('int')
c[c=='0'] = 'b' #negative diagnosis diabetes
c[c=='1'] = 'r' #positive diagnosis diabetes

fig = plt.figure(figsize=(18,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(feature1, feature2, feature3, c=c)
ax.set_xlabel('mass_shape')
ax.set_ylabel('mass_density')
ax.set_zlabel('mass_margin')

plt.show()

# %%
#exploring feature space import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

feature1 = df['mass_shape'].values
feature2 = df['mass_density'].values 
feature3 = df['mass_margin'].values

df['class']=df['class'].astype('str')

c = df['class'].values
df['class']=df['class'].astype('int')
c[c=='0'] = 'b' #benign
c[c=='1'] = 'r' #malignant

fig = plt.figure(figsize=(14,8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(feature1, feature2, feature3, c=c)
ax.set_xlabel('mass_shape')
ax.set_ylabel('mass_density')
ax.set_zlabel('mass_margin')

plt.show()

# %%
standardscaler 
one hot encoder
PCa
